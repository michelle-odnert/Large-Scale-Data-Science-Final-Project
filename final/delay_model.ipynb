# %%
'''
delay_model.ipynb
notebook containing delay_model and training
'''

# %% [markdown]
# given features:
#
# bpiuc
# day
# time
# ...
#
# these features are the fields entered to get delay-time estimates and confidence levels for specific routes
