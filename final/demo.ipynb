# %%
''' 
demo.ipynb
final notebook, easily run by the user to see interactive routing map
'''

# %% [markdown]
# calls a main function from demo_app.py for cleanliness,
# all visuals/interactive code will be in vis.py

# %%
from demo_app import run_demo

run_demo()
